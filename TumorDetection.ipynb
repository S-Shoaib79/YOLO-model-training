# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 35.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")

train_results = model.train(
    data = "/content/drive/MyDrive/tumor data/Tumor_Detection/data.yaml",
    epochs = 20,
    imgsz = 640,
    device = 0
    )
# Out:
# Ultralytics 8.3.102 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("/content/runs/detect/train4/weights/best.pt")
results = model("/content/images/glioma.jpg", save = True)
results[0].show()
# Out:
# image 1/1 /content/images/glioma.jpg: 640x640 1 glioma, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
model = YOLO("/content/runs/detect/train4/weights/best.pt")
results = model("/content/images", save = True)
# Out:
# image 1/4 /content/images/glioma.jpg: 640x640 1 glioma, 8.1ms
# image 2/4 /content/images/meningioma.jpg: 640x640 1 meningioma, 8.3ms
# image 3/4 /content/images/notumor.jpg: 640x640 1 NO_tumor, 8.1ms
# image 4/4 /content/images/pituitary.jpg: 640x640 1 pituitary, 9.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5

# %%
for result in results:
  boxes = result.boxes
  print(boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([1.], device='cuda:0')
# conf: tensor([0.9170], device='cuda:0')
# data: tensor([[435.3830, 298.1702, 471.5086, 331.6177,   0.9170,   1.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[453.4458, 314.8939,  36.1257,  33.4475]], device='cuda:0')
# xywhn: tensor([[0.7085, 0.4920, 0.0564, 0.0523]], device='cuda:0')
# xyxy: tensor([[435.3830, 298.1702, 471.5086, 331.6177]], device='cuda:0')
# xyxyn: tensor([[0.6803, 0.4659, 0.7367, 0.5182]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.9361], device='cuda:0')
# data: tensor([[234.1475, 263.7987, 314.3326, 343.4864,   0.9361,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([1, 6])
# ...

# %%
from ultralytics import SAM
sam = SAM("sam2_b.pt")

for result in results:
  class_ids = result.boxes.cls.int().tolist()
  if len(class_ids):
    boxes = result.boxes.xyxy
    sam_results = sam(result.orig_img, bboxes = boxes, verbose = False, save = True, device = 0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2c93526668c7> in <cell line: 0>()
# ----> 1 from ultralytics import SAM
#       2 sam = SAM("sam2_b.pt")
#       3
#       4 for result in results:
#       5   class_ids = result.boxes.cls.int().tolist()
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
